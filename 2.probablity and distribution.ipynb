# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %matplotlib inline

# %%
# Generate random data (normal distribution)
data = np.random.normal(loc=50, scale=10, size=1000)

# %%
# Probability example
prob = np.sum(data > 60) / len(data)
print("Probability that value > 60:", prob)
# Out:
# Probability that value > 60: 0.175

# %%
plt.hist(data, bins=30, density=True, alpha=0.6, color='g', label='Histogram')
# Out:
# (array([0.00096376, 0.        , 0.00048188, 0.00144564, 0.00385503,
#         0.00337315, 0.00722818, 0.01156509, 0.0134926 , 0.01879327,
#         0.02794896, 0.02794896, 0.03903217, 0.04047781, 0.03421338,
#         0.04192344, 0.0361409 , 0.03084023, 0.03084023, 0.0269852 ,
#         0.02072078, 0.02120266, 0.01782951, 0.00963757, 0.00289127,
#         0.00626442, 0.00240939, 0.00240939, 0.00048188, 0.00048188]),
#  array([18.55825196, 20.63346319, 22.70867442, 24.78388565, 26.85909688,
#         28.93430811, 31.00951934, 33.08473057, 35.1599418 , 37.23515303,
#         39.31036426, 41.38557549, 43.46078672, 45.53599795, 47.61120918,
#         49.68642042, 51.76163165, 53.83684288, 55.91205411, 57.98726534,
#         60.06247657, 62.1376878 , 64.21289903, 66.28811026, 68.36332149,
#         70.43853272, 72.51374395, 74.58895518, 76.66416641, 78.73937764,
#         80.81458887]),
#  <BarContainer object of 30 artists>)

# %%
mean = np.mean(data)
std = np.std(data)

x = np.linspace(min(data), max(data), 100)
y = norm.pdf(x, mean, std)

plt.plot(x, y, 'r', label='Normal Distribution Curve')

# %%
plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.title('Probability & Distribution')
plt.legend()

plt.show()
